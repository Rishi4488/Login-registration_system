# %% [markdown]
# <a href="https://colab.research.google.com/github/Rishi4488/assignment1/blob/main/Assessment2B.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ###### Assessment

# %% [markdown]
# ###### I am going to provide two .csv files , you are supposed to work on them and have to provide solutions to the following problems

# %% [markdown]
# ###### import necessary libraries

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ###### merge those two csv files (after getting as dataframes, get them as a single dataframe)

# %%
csv1 = pd.read_csv("college_1.csv")
csv1.head()
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
# 3  Mugunthan S   100.0   47.0              10610           10610
# 4  Sathammai.S   100.0    8.0               8980            8980
#
#                          Department  Rising
# 0  Computer Science and Engineering       0
# 1  Computer Science and Engineering       0
# 2  Computer Science and Engineering       0
# 3  Computer Science and Engineering       0
# 4  Computer Science and Engineering       0

# %%
csv2 = pd.read_csv("college_2.csv")
csv2.head()
# Out:
#                 Name  python  python_en  mysql  computational_thinking  \
# 0      ASHOK KUMAR K     100          0     31                       9
# 1            Chandru       0         20      0                       0
# 2  Ganesh Ramkumar R      -1         55     24                       6
# 3    Bodipudi Harini      -1          0     35                      -1
# 4          VIINU V P      -1        100     24                      -1
#
#    Previous Geekions  CodeKata Score  \
# 0              19400           19400
# 1              14150           14490
# 2               8790           10790
# 3              10040           10040
# 4               9150            9150
#
#                                   Department  Rising
# 0     Electronics and Electrical Engineering       0
# 1           Computer Science and Engineering     340
# 2           Computer Science and Engineering    2000
# 3  Electronics and Communication Engineering       0
# ...

# %%
df = pd.concat([csv1,csv2])
df.to_csv('college_1&2.csv',index=False)
df_csv = pd.read_csv('college_1&2.csv')
df_csv
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1      V.JEEVITHA     82.0   20.0              21740           21740
# 2      HEMAVATHI.R   100.0  100.0              19680           19680
# 3      Mugunthan S   100.0   47.0              10610           10610
# 4      Sathammai.S   100.0    8.0               8980            8980
# ..             ...     ...    ...                ...             ...
# 114  praveen raj j    24.0    0.0               2380            2380
# 115     AMARNATH D    -1.0   12.0               1890            1890
# 116           bala    32.0    0.0               1720            1720
# 117           XY Z    -1.0   -1.0                  0               0
# 118      Hariharan    -1.0   -1.0                  0               0
#
#                                     Department  Rising  python_en  \
# 0             Computer Science and Engineering       0        NaN
# ...

# %% [markdown]
# ###### Take each csv file , split that csv file into multiple categories (example csv files are added in the repo)

# %% [markdown]
# ###### consider if the codekata score exceeds 15000 points(present week) then make a csv on those observations as Exceeded expectations.csv

# %% [markdown]
# ###### if  10000<codekata score<15000   (Reached_expectations.csv)

# %% [markdown]
# ###### if  7000<codekata score<10000   (Needs_Improvement.csv)

# %% [markdown]
# ###### if  codekate score < 7000        (Unsatisfactory.csv)

# %%
above_15000 = df_csv[df_csv["CodeKata Score"]>15000]
above_15000.to_csv('Exceeded_expectations.csv',index=False)
df_csv1 = pd.read_csv('Exceeded_expectations.csv')
df_csv1
# Out:
#             Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0      A.Dharani    82.0   20.0              24500           24500
# 1    V.JEEVITHA     82.0   20.0              21740           21740
# 2    HEMAVATHI.R   100.0  100.0              19680           19680
# 3  ASHOK KUMAR K   100.0   31.0              19400           19400
#
#                                Department  Rising  python_en  \
# 0        Computer Science and Engineering       0        NaN
# 1        Computer Science and Engineering       0        NaN
# 2        Computer Science and Engineering       0        NaN
# 3  Electronics and Electrical Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     NaN
# 2                     NaN
# 3                     9.0

# %%
above_10000 = df_csv[df_csv["CodeKata Score"].between(10000,15000)]
above_10000.to_csv('Reached_expectations.csv',index=False)
df_csv2 = pd.read_csv('Reached_expectations.csv')
df_csv2
# Out:
#                 Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        Mugunthan S   100.0   47.0              10610           10610
# 1            Chandru     0.0    0.0              14150           14490
# 2  Ganesh Ramkumar R    -1.0   24.0               8790           10790
# 3    Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising  python_en  \
# 0           Computer Science and Engineering       0        NaN
# 1           Computer Science and Engineering     340       20.0
# 2           Computer Science and Engineering    2000       55.0
# 3  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     0.0
# 2                     6.0
# 3                    -1.0

# %%
above_7000 = df_csv[df_csv["CodeKata Score"].between(7000,10000)]
above_7000.to_csv('Needs_Improvement.csv',index=False)
df_csv3 = pd.read_csv('Needs_Improvement.csv')
df_csv3
# Out:
#                       Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0              Sathammai.S   100.0    8.0               8980            8980
# 1             NIVEESHWAR S   100.0    0.0               8200            8200
# 2            KALAIARASAN K    85.0   47.0               7750            7880
# 3     MOHAMED ZUBAIR AHMED    82.0    4.0               7020            7020
# 4                VIINU V P    -1.0   24.0               9150            9150
# 5               Poojitha Y     0.0   35.0               7210            8970
# 6   Gowtham Chandrasekaran    -1.0    0.0               7250            8950
# 7                Gowtham R    -1.0    4.0               8650            8650
# 8                 shifak N    58.0    0.0               5180            8320
# 9                  Balaji     -1.0   20.0               6170            8160
# 10                Rushitha    -1.0   62.0               7470            8090
# ...

# %%
below_7000 = df_csv[df_csv["CodeKata Score"]<7000]
below_7000.to_csv('Unsatisfactory.csv',index=False)
df_csv4 = pd.read_csv('Unsatisfactory.csv')
df_csv4
# Out:
#                Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        J.SUGANTHI    27.0  50.00               5860            5860
# 1      thamizhpaana    29.0   0.00               5500            5500
# 2   Iyappan Samiraj    50.0  24.00               5400            5400
# 3      Ponniyamma.R   100.0  11.25               5380            5380
# 4         SABAPATHI   100.0   0.00               5280            5280
# ..              ...     ...    ...                ...             ...
# 88    praveen raj j    24.0   0.00               2380            2380
# 89       AMARNATH D    -1.0  12.00               1890            1890
# 90             bala    32.0   0.00               1720            1720
# 91             XY Z    -1.0  -1.00                  0               0
# 92        Hariharan    -1.0  -1.00                  0               0
#
#                                    Department  Rising  python_en  \
# ...

# %% [markdown]
# ###### Average of previous week geekions vs this week geekions (i.e Previous Geekions vs CodeKata Score)

# %%
mean_Geekions = df_csv['Previous Geekions'].mean()
mean_Geekions
# Out:
# 3842.3529411764707

# %%
mean_CodeKata_Score = df_csv['CodeKata Score'].mean()
mean_CodeKata_Score
# Out:
# 4051.764705882353

# %%
mean_Geekions = df_csv['Previous Geekions'].mean()
mean_CodeKata_Score = df_csv['CodeKata Score'].mean()
if mean_CodeKata_Score > mean_Geekions:
  print('Average of CodeKata Score is greater than the Average of Previous Geekions')
else:
  print('Average of Previous Geekions is greater than the Average of CodeKata Score')
# Out:
# Average of CodeKata Score is greater than the Average of Previous Geekions

# %% [markdown]
# ###### No of students participated

# %%
a = df_csv['Name'].count()
print("Number of students participated:",a)
# Out:
# Number of students participated: 119

# %% [markdown]
# ###### #Average completion of python course or my_sql or python english or computational thinking

# %%
Average_completion_python_course = df_csv['python'].mean()
Average_completion_python_course
# Out:
# 54.35294117647059

# %%
Average_completion_my_sql = df_csv['mysql'].mean()
Average_completion_my_sql
# Out:
# 23.5

# %%
Average_completion_python_english = df_csv['python_en'].mean()
Average_completion_python_english
# Out:
# 29.65714285714286

# %%
Average_completion_computational_thinking = df_csv['computational_thinking'].mean()
Average_completion_computational_thinking
# Out:
# 2.2

# %% [markdown]
# ###### rising star of the week (top 3 candidate who performed well in that particular week)

# %%
s=df_csv.sort_values(by=['Rising'],ascending=False)
s.head(3)
# Out:
#                   Name  python  mysql  Previous Geekions  CodeKata Score  \
# 92            shifak N    58.0    0.0               5180            8320
# 102     Narasimhan Y L    -1.0    0.0               4800            6800
# 86   Ganesh Ramkumar R    -1.0   24.0               8790           10790
#
#                                  Department  Rising  python_en  \
# 92   Electronics and Electrical Engineering    3140        0.0
# 102        Computer Science and Engineering    2000       -1.0
# 86         Computer Science and Engineering    2000       55.0
#
#      computational_thinking
# 92                      0.0
# 102                     0.0
# 86                      6.0

# %% [markdown]
# ###### Shining stars of the week (top 3 candidates who has highest geekions)

# %%
s=df_csv.sort_values(by=['Previous Geekions'],ascending=False)
s.head(3)
# Out:
#           Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0    A.Dharani    82.0   20.0              24500           24500
# 1  V.JEEVITHA     82.0   20.0              21740           21740
# 2  HEMAVATHI.R   100.0  100.0              19680           19680
#
#                          Department  Rising  python_en  computational_thinking
# 0  Computer Science and Engineering       0        NaN                     NaN
# 1  Computer Science and Engineering       0        NaN                     NaN
# 2  Computer Science and Engineering       0        NaN                     NaN

# %% [markdown]
# ###### Department wise codekata performence (pie chart)

# %%
df1 = pd.read_csv("college_1&2.csv")
data = {'CodeKata Score':'sum_CodeKata_Score'}
agg_data = {'CodeKata Score':'sum'}
data_bar = df1.groupby(['Department'], as_index=False).agg(agg_data).rename(columns=data)
data_bar
# Out:
#                                   Department  sum_CodeKata_Score
# 0           Computer Science and Engineering              320025
# 1  Electronics and Communication Engineering              108335
# 2     Electronics and Electrical Engineering               53800

# %%
y1=[320025,108335,53800]  
mylabels = ["Computer Science and Engineering	","Electronics and Communication Engineering","Electronics and Electrical Engineering	"]
plt.pie(y1,labels= mylabels,autopct='%1.0f%%')
plt.title('Department wise codekata performence (pie chart)')  
plt.show()
# Out:
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:214: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0.0, flags=flags)
# /usr/local/lib/python3.7/dist-packages/matplotlib/backends/backend_agg.py:183: RuntimeWarning: Glyph 9 missing from current font.
#   font.set_text(s, 0, flags=flags)

# %% [markdown]
# ###### Department wise toppers (horizantal bar graph or any visual representations of your choice)

# %%
df1 = pd.read_csv("college_1&2.csv")
data = {'CodeKata Score':'sum_CodeKata_Score'}
agg_data = {'CodeKata Score':'max'}
data_bar = df1.groupby(['Department'], as_index=False).agg(agg_data)
data_bar
# Out:
#                                   Department  CodeKata Score
# 0           Computer Science and Engineering           24500
# 1  Electronics and Communication Engineering           10040
# 2     Electronics and Electrical Engineering           19400

# %%
df_csv = pd.read_csv('college_1&2.csv')
tdf = df_csv.iloc[[0,84,87]]
tdf.to_csv('toppers.csv',index=False)
tdf1 = pd.read_csv('toppers.csv')
tdf1
# Out:
#               Name  python  mysql  Previous Geekions  CodeKata Score  \
# 0        A.Dharani    82.0   20.0              24500           24500
# 1    ASHOK KUMAR K   100.0   31.0              19400           19400
# 2  Bodipudi Harini    -1.0   35.0              10040           10040
#
#                                   Department  Rising  python_en  \
# 0           Computer Science and Engineering       0        NaN
# 1     Electronics and Electrical Engineering       0        0.0
# 2  Electronics and Communication Engineering       0        0.0
#
#    computational_thinking
# 0                     NaN
# 1                     9.0
# 2                    -1.0

# %%
tdf1.plot.barh(x='Name',y='CodeKata Score',title='Department wise toppers',color='Blue')
